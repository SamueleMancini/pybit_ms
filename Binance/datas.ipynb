# %%
from funcs import convert_date_to_timestamp, convert_timestamp_to_date, get_historical_klines, format_kline_response, read_last_time_up
import csv
import time

# %% [markdown]
# 2024 tots: 360, 72, 6
# 2022 tots: 133, 27, 3
# final: 1595, 319, 26

# %%
COINS = ["AVAX"]

# %% [markdown]
# # 1 min

# %%
exceptions = []

for coin in COINS:
    n = 0
    last_time = '2021-09-01 00:00'
    first = 1
    symbol = f'{coin}USDT'
    interval = '1m'
    file_name = f'{coin}usdt_1m.csv'
    tot = 1595

    for i in range(tot):
        if coin == "PEPE":
            break
        try:
            start_str = convert_date_to_timestamp(last_time)
            
            klines = get_historical_klines(symbol, interval, start_str)
            last_time = read_last_time_up(convert_timestamp_to_date(klines[-1][6]))
            data = format_kline_response(klines)

            if first:
                with open(file_name, mode='w', newline='') as file:
                    writer = csv.DictWriter(file, fieldnames=data[0].keys())
                    writer.writeheader()      
                    for row in data:
                        writer.writerow(row)

                print(f'{n}/{tot}:    Data written to {file_name} until hours {last_time}')
                first = 0

            else:
                with open(file_name, mode='a', newline='') as file:
                    writer = csv.DictWriter(file, fieldnames=data[0].keys())     
                    for row in data:
                        writer.writerow(row)

                print(f'{n}/{tot}:    Data written to {file_name} until hours {last_time}')
            n += 1
            time.sleep(0.1)
        except:
            exceptions.append(f"{coin}_{interval}")
            break


    n = 0
    last_time = '2021-09-01 00:00'
    first = 1
    symbol = f'{coin}USDT'
    interval = '5m'
    file_name = f'{coin}usdt_5m.csv'
    tot = 319

    for i in range(tot):
        try:
            start_str = convert_date_to_timestamp(last_time)

            klines = get_historical_klines(symbol, interval, start_str)
            last_time = read_last_time_up(convert_timestamp_to_date(klines[-1][6]))

            data = format_kline_response(klines)

            if first:
                with open(file_name, mode='w', newline='') as file:
                    writer = csv.DictWriter(file, fieldnames=data[0].keys())
                    writer.writeheader()      
                    for row in data:
                        writer.writerow(row)

                print(f'{n}/{tot}:    Data written to {file_name} until hours {last_time}')
                first = 0

            else:
                with open(file_name, mode='a', newline='') as file:
                    writer = csv.DictWriter(file, fieldnames=data[0].keys())     
                    for row in data:
                        writer.writerow(row)

                print(f'{n}/{tot}:    Data written to {file_name} until hours {last_time}')
            n += 1
            time.sleep(0.1)
        except:
            exceptions.append(f"{coin}_{interval}")
            break



    n = 0
    last_time = '2021-09-01 00:00'
    first = 1
    symbol = f'{coin}USDT'
    interval = '1h'
    file_name = f'{coin}usdt_60m.csv'
    tot = 27


    for i in range(tot):
        try:
            start_str = convert_date_to_timestamp(last_time)

            klines = get_historical_klines(symbol, interval, start_str)
            last_time = read_last_time_up(convert_timestamp_to_date(klines[-1][6]))

            data = format_kline_response(klines)

            if first:
                with open(file_name, mode='w', newline='') as file:
                    writer = csv.DictWriter(file, fieldnames=data[0].keys())
                    writer.writeheader()      
                    for row in data:
                        writer.writerow(row)

                print(f'{n}/{tot}:    Data written to {file_name} until hours {last_time}')
                first = 0

            else:
                with open(file_name, mode='a', newline='') as file:
                    writer = csv.DictWriter(file, fieldnames=data[0].keys())     
                    for row in data:
                        writer.writerow(row)

                print(f'{n}/{tot}:    Data written to {file_name} until hours {last_time}')
            n += 1
            time.sleep(0.1)
        except:
            exceptions.append(f"{coin}_{interval}")
            break
# Out:
# 0/1595:    Data written to BTCusdt_1m.csv until hours 2021-09
1595:    Data written to BTCusdt_1m.csv until hours 2022-10-20 16:00
# 597/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-21 08:40
# 598/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-22 01:20
# 599/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-22 18:00
# 600/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-23 10:40
# 601/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-24 03:20
# 602/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-24 20:00
# 603/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-25 12:40
# 604/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-26 05:20
# 605/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-26 22:00
# 606/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-27 14:40
# 607/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-28 07:20
# 608/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-29 00:00
# 609/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-29 16:40
# 610/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-30 08:20
# 611/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-31 01:00
# 612/1595:    Data written to BTCusdt_1m.csv until hours 2022-10-31 17:40
# 613/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-01 10:20
# 614/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-02 03:00
# 615/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-02 19:40
# 616/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-03 12:20
# 617/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-04 05:00
# 618/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-04 21:40
# 619/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-05 14:20
# 620/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-06 07:00
# 621/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-06 23:40
# 622/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-07 16:20
# 623/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-08 09:00
# 624/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-09 01:40
# 625/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-09 18:20
# 626/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-10 11:00
# 627/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-11 03:40
# 628/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-11 20:20
# 629/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-12 13:00
# 630/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-13 05:40
# 631/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-13 22:20
# 632/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-14 15:00
# 633/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-15 07:40
# 634/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-16 00:20
# 635/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-16 17:00
# 636/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-17 09:40
# 637/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-18 02:20
# 638/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-18 19:00
# 639/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-19 11:40
# 640/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-20 04:20
# 641/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-20 21:00
# 642/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-21 13:40
# 643/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-22 06:20
# 644/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-22 23:00
# 645/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-23 15:40
# 646/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-24 08:20
# 647/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-25 01:00
# 648/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-25 17:40
# 649/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-26 10:20
# 650/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-27 03:00
# 651/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-27 19:40
# 652/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-28 12:20
# 653/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-29 05:00
# 654/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-29 21:40
# 655/1595:    Data written to BTCusdt_1m.csv until hours 2022-11-30 14:20
# 656/1595:    Data written to BTCusdt_1m.csv until hours 2022-12-01 07:00
# 657/1595:    Data written to BTCusdt_1m.csv until hours 2022-12-01 23:40
# 658/1595:    Data written to BTCusdt_1m.csv until hours 2022-12-02 16:20
# ...
# 127/319:    Data written to AVAXusdt_5m.csv until hours 2022-11-19 11:40
# 128/319:    Data written to AVAXusdt_5m.csv until hours 2022-11-22 23:00
# 129/319:    Data written to AVAXusdt_5m.csv until hours 2022-11-26 10:20
# 130/319:    Data written to AVAXusdt_5m.csv until hours 2022-11-29 21:40
# 131/319:    Data written to AVAXusdt_5m.csv until hours 2022-12-03 09:00
# 132/319:    Data written to AVAXusdt_5m.csv until hours 2022-12-06 20:20
# 133/319:    Data written to AVAXusdt_5m.csv until hours 2022-12-10 07:40
# 134/319:    Data written to AVAXusdt_5m.csv until hours 2022-12-13 19:00
# 135/319:    Data written to AVAXusdt_5m.csv until hours 2022-12-17 06:20
# 136/319:    Data written to AVAXusdt_5m.csv until hours 2022-12-20 17:40
# 137/319:    Data written to AVAXusdt_5m.csv until hours 2022-12-24 05:00
# 138/319:    Data written to AVAXusdt_5m.csv until hours 2022-12-27 16:20
# 139/319:    Data written to AVAXusdt_5m.csv until hours 2022-12-31 03:40
# 140/319:    Data written to AVAXusdt_5m.csv until hours 2023-01-03 15:00
# 141/319:    Data written to AVAXusdt_5m.csv until hours 2023-01-07 02:20
# 142/319:    Data written to AVAXusdt_5m.csv until hours 2023-01-10 13:40
# 143/319:    Data written to AVAXusdt_5m.csv until hours 2023-01-14 01:00
# 144/319:    Data written to AVAXusdt_5m.csv until hours 2023-01-17 12:20
# 145/319:    Data written to AVAXusdt_5m.csv until hours 2023-01-20 23:40
# 146/319:    Data written to AVAXusdt_5m.csv until hours 2023-01-24 11:00
# 147/319:    Data written to AVAXusdt_5m.csv until hours 2023-01-27 22:20
# 148/319:    Data written to AVAXusdt_5m.csv until hours 2023-01-31 09:40
# 149/319:    Data written to AVAXusdt_5m.csv until hours 2023-02-03 21:00
# 150/319:    Data written to AVAXusdt_5m.csv until hours 2023-02-07 08:20
# 151/319:    Data written to AVAXusdt_5m.csv until hours 2023-02-10 19:40
# 152/319:    Data written to AVAXusdt_5m.csv until hours 2023-02-14 07:00
# 153/319:    Data written to AVAXusdt_5m.csv until hours 2023-02-17 18:20
# 154/319:    Data written to AVAXusdt_5m.csv until hours 2023-02-21 05:40
# 155/319:    Data written to AVAXusdt_5m.csv until hours 2023-02-24 17:00
# 156/319:    Data written to AVAXusdt_5m.csv until hours 2023-02-28 04:20
# 157/319:    Data written to AVAXusdt_5m.csv until hours 2023-03-03 15:40
# 158/319:    Data written to AVAXusdt_5m.csv until hours 2023-03-07 03:00
# 159/319:    Data written to AVAXusdt_5m.csv until hours 2023-03-10 14:20
# 160/319:    Data written to AVAXusdt_5m.csv until hours 2023-03-14 01:40
# 161/319:    Data written to AVAXusdt_5m.csv until hours 2023-03-17 13:00
# 162/319:    Data written to AVAXusdt_5m.csv until hours 2023-03-21 00:20
# 163/319:    Data written to AVAXusdt_5m.csv until hours 2023-03-24 11:40
# 164/319:    Data written to AVAXusdt_5m.csv until hours 2023-03-28 01:20
# 165/319:    Data written to AVAXusdt_5m.csv until hours 2023-03-31 12:40
# 166/319:    Data written to AVAXusdt_5m.csv until hours 2023-04-04 00:00
# 167/319:    Data written to AVAXusdt_5m.csv until hours 2023-04-07 11:20
# 168/319:    Data written to AVAXusdt_5m.csv until hours 2023-04-10 22:40
# 169/319:    Data written to AVAXusdt_5m.csv until hours 2023-04-14 10:00
# 170/319:    Data written to AVAXusdt_5m.csv until hours 2023-04-17 21:20
# 171/319:    Data written to AVAXusdt_5m.csv until hours 2023-04-21 08:40
# 172/319:    Data written to AVAXusdt_5m.csv until hours 2023-04-24 20:00
# 173/319:    Data written to AVAXusdt_5m.csv until hours 2023-04-28 07:20
# 174/319:    Data written to AVAXusdt_5m.csv until hours 2023-05-01 18:40
# 175/319:    Data written to AVAXusdt_5m.csv until hours 2023-05-05 06:00
# 176/319:    Data written to AVAXusdt_5m.csv until hours 2023-05-08 17:20
# 177/319:    Data written to AVAXusdt_5m.csv until hours 2023-05-12 04:40
# 178/319:    Data written to AVAXusdt_5m.csv until hours 2023-05-15 16:00
# 179/319:    Data written to AVAXusdt_5m.csv until hours 2023-05-19 03:20
# 180/319:    Data written to AVAXusdt_5m.csv until hours 2023-05-22 14:40
# 181/319:    Data written to AVAXusdt_5m.csv until hours 2023-05-26 02:00
# 182/319:    Data written to AVAXusdt_5m.csv until hours 2023-05-29 13:20
# 183/319:    Data written to AVAXusdt_5m.csv until hours 2023-06-02 00:40
# 184/319:    Data written to AVAXusdt_5m.csv until hours 2023-06-05 12:00
# 185/319:    Data written to AVAXusdt_5m.csv until hours 2023-06-08 23:20
# 186/319:    Data written to AVAXusdt_5m.csv until hours 2023-06-12 10:40
# 187/319:    Data written to AVAXusdt_5m.csv until hours 2023-06-15 22:00
# 188/319:    Data written to AVAXusdt_5m.csv until hours 2023-06-19 09:20
# 189/319:    Data written to AVAXusdt_5m.csv until hours 2023-06-22 20:40
# 190/319:    Data written to AVAXusdt_5m.csv until hours 2023-06-26 08:00
# 191/319:    Data written to AVAXusdt_5m.csv until hours 2023-06-29 19:20
# 192/319:    Data written to AVAXusdt_5m.csv until hours 2023-07-03 06:40
# 193/319:    Data written to AVAXusdt_5m.csv until hours 2023-07-06 18:00
# 194/319:    Data written to AVAXusdt_5m.csv until hours 2023-07-10 05:20
# 195/319:    Data written to AVAXusdt_5m.csv until hours 2023-07-13 16:40
# 196/319:    Data written to AVAXusdt_5m.csv until hours 2023-07-17 04:00
# 197/319:    Data written to AVAXusdt_5m.csv until hours 2023-07-20 15:20
# 198/319:    Data written to AVAXusdt_5m.csv until hours 2023-07-24 02:40
# 199/319:    Data written to AVAXusdt_5m.csv until hours 2023-07-27 14:00
# 200/319:    Data written to AVAXusdt_5m.csv until hours 2023-07-31 01:20
# 201/319:    Data written to AVAXusdt_5m.csv until hours 2023-08-03 12:40
# 202/319:    Data written to AVAXusdt_5m.csv until hours 2023-08-07 00:00
# 203/319:    Data written to AVAXusdt_5m.csv until hours 2023-08-10 11:20
# 204/319:    Data written to AVAXusdt_5m.csv until hours 2023-08-13 22:40
# 205/319:    Data written to AVAXusdt_5m.csv until hours 2023-08-17 10:00
# 206/319:    Data written to AVAXusdt_5m.csv until hours 2023-08-20 21:20
# 207/319:    Data written to AVAXusdt_5m.csv until hours 2023-08-24 08:40
# 208/319:    Data written to AVAXusdt_5m.csv until hours 2023-08-27 20:00
# 209/319:    Data written to AVAXusdt_5m.csv until hours 2023-08-31 07:20
# 210/319:    Data written to AVAXusdt_5m.csv until hours 2023-09-03 18:40
# 211/319:    Data written to AVAXusdt_5m.csv until hours 2023-09-07 06:00
# 212/319:    Data written to AVAXusdt_5m.csv until hours 2023-09-10 17:20
# 213/319:    Data written to AVAXusdt_5m.csv until hours 2023-09-14 04:40
# 214/319:    Data written to AVAXusdt_5m.csv until hours 2023-09-17 16:00
# 215/319:    Data written to AVAXusdt_5m.csv until hours 2023-09-21 03:20
# 216/319:    Data written to AVAXusdt_5m.csv until hours 2023-09-24 14:40
# 217/319:    Data written to AVAXusdt_5m.csv until hours 2023-09-28 02:00
# 218/319:    Data written to AVAXusdt_5m.csv until hours 2023-10-01 13:20
# 219/319:    Data written to AVAXusdt_5m.csv until hours 2023-10-05 00:40
# 220/319:    Data written to AVAXusdt_5m.csv until hours 2023-10-08 12:00
# 221/319:    Data written to AVAXusdt_5m.csv until hours 2023-10-11 23:20
# 222/319:    Data written to AVAXusdt_5m.csv until hours 2023-10-15 10:40
# 223/319:    Data written to AVAXusdt_5m.csv until hours 2023-10-18 22:00
# 224/319:    Data written to AVAXusdt_5m.csv until hours 2023-10-22 09:20
# 225/319:    Data written to AVAXusdt_5m.csv until hours 2023-10-25 20:40
# 226/319:    Data written to AVAXusdt_5m.csv until hours 2023-10-29 07:00
# 227/319:    Data written to AVAXusdt_5m.csv until hours 2023-11-01 18:20
# 228/319:    Data written to AVAXusdt_5m.csv until hours 2023-11-05 05:40
# 229/319:    Data written to AVAXusdt_5m.csv until hours 2023-11-08 17:00
# 230/319:    Data written to AVAXusdt_5m.csv until hours 2023-11-12 04:20
# 231/319:    Data written to AVAXusdt_5m.csv until hours 2023-11-15 15:40
# 232/319:    Data written to AVAXusdt_5m.csv until hours 2023-11-19 03:00
# 233/319:    Data written to AVAXusdt_5m.csv until hours 2023-11-22 14:20
# 234/319:    Data written to AVAXusdt_5m.csv until hours 2023-11-26 01:40
# 235/319:    Data written to AVAXusdt_5m.csv until hours 2023-11-29 13:00
# 236/319:    Data written to AVAXusdt_5m.csv until hours 2023-12-03 00:20
# 237/319:    Data written to AVAXusdt_5m.csv until hours 2023-12-06 11:40
# 238/319:    Data written to AVAXusdt_5m.csv until hours 2023-12-09 23:00
# 239/319:    Data written to AVAXusdt_5m.csv until hours 2023-12-13 10:20
# 240/319:    Data written to AVAXusdt_5m.csv until hours 2023-12-16 21:40
# 241/319:    Data written to AVAXusdt_5m.csv until hours 2023-12-20 09:00
# 242/319:    Data written to AVAXusdt_5m.csv until hours 2023-12-23 20:20
# 243/319:    Data written to AVAXusdt_5m.csv until hours 2023-12-27 07:40
# 244/319:    Data written to AVAXusdt_5m.csv until hours 2023-12-30 19:00
# 245/319:    Data written to AVAXusdt_5m.csv until hours 2024-01-03 06:20
# 246/319:    Data written to AVAXusdt_5m.csv until hours 2024-01-06 17:40
# 247/319:    Data written to AVAXusdt_5m.csv until hours 2024-01-10 05:00
# 248/319:    Data written to AVAXusdt_5m.csv until hours 2024-01-13 16:20
# 249/319:    Data written to AVAXusdt_5m.csv until hours 2024-01-17 03:40
# 250/319:    Data written to AVAXusdt_5m.csv until hours 2024-01-20 15:00
# 251/319:    Data written to AVAXusdt_5m.csv until hours 2024-01-24 02:20
# 252/319:    Data written to AVAXusdt_5m.csv until hours 2024-01-27 13:40
# 253/319:    Data written to AVAXusdt_5m.csv until hours 2024-01-31 01:00
# 254/319:    Data written to AVAXusdt_5m.csv until hours 2024-02-03 12:20
# 255/319:    Data written to AVAXusdt_5m.csv until hours 2024-02-06 23:40
# 256/319:    Data written to AVAXusdt_5m.csv until hours 2024-02-10 11:00
# 257/319:    Data written to AVAXusdt_5m.csv until hours 2024-02-13 22:20
# 258/319:    Data written to AVAXusdt_5m.csv until hours 2024-02-17 09:40
# 259/319:    Data written to AVAXusdt_5m.csv until hours 2024-02-20 21:00
# 260/319:    Data written to AVAXusdt_5m.csv until hours 2024-02-24 08:20
# 261/319:    Data written to AVAXusdt_5m.csv until hours 2024-02-27 19:40
# 262/319:    Data written to AVAXusdt_5m.csv until hours 2024-03-02 07:00
# 263/319:    Data written to AVAXusdt_5m.csv until hours 2024-03-05 18:20
# 264/319:    Data written to AVAXusdt_5m.csv until hours 2024-03-09 05:40
# 265/319:    Data written to AVAXusdt_5m.csv until hours 2024-03-12 17:00
# 266/319:    Data written to AVAXusdt_5m.csv until hours 2024-03-16 04:20
# 267/319:    Data written to AVAXusdt_5m.csv until hours 2024-03-19 15:40
# 268/319:    Data written to AVAXusdt_5m.csv until hours 2024-03-23 03:00
# 269/319:    Data written to AVAXusdt_5m.csv until hours 2024-03-26 14:20
# 270/319:    Data written to AVAXusdt_5m.csv until hours 2024-03-30 01:40
# 271/319:    Data written to AVAXusdt_5m.csv until hours 2024-04-02 14:00
# 272/319:    Data written to AVAXusdt_5m.csv until hours 2024-04-06 01:20
# 273/319:    Data written to AVAXusdt_5m.csv until hours 2024-04-09 12:40
# 274/319:    Data written to AVAXusdt_5m.csv until hours 2024-04-13 00:00
# 275/319:    Data written to AVAXusdt_5m.csv until hours 2024-04-16 11:20
# 276/319:    Data written to AVAXusdt_5m.csv until hours 2024-04-19 22:40
# 277/319:    Data written to AVAXusdt_5m.csv until hours 2024-04-23 10:00
# 278/319:    Data written to AVAXusdt_5m.csv until hours 2024-04-26 21:20
# 279/319:    Data written to AVAXusdt_5m.csv until hours 2024-04-30 08:40
# 280/319:    Data written to AVAXusdt_5m.csv until hours 2024-05-03 20:00
# 281/319:    Data written to AVAXusdt_5m.csv until hours 2024-05-07 07:20
# 282/319:    Data written to AVAXusdt_5m.csv until hours 2024-05-10 18:40
# 283/319:    Data written to AVAXusdt_5m.csv until hours 2024-05-14 06:00
# 284/319:    Data written to AVAXusdt_5m.csv until hours 2024-05-17 17:20
# 285/319:    Data written to AVAXusdt_5m.csv until hours 2024-05-21 04:40
# 286/319:    Data written to AVAXusdt_5m.csv until hours 2024-05-24 16:00
# 287/319:    Data written to AVAXusdt_5m.csv until hours 2024-05-28 03:20
# 288/319:    Data written to AVAXusdt_5m.csv until hours 2024-05-31 14:40
# 289/319:    Data written to AVAXusdt_5m.csv until hours 2024-06-04 02:00
# 290/319:    Data written to AVAXusdt_5m.csv until hours 2024-06-07 13:20
# 291/319:    Data written to AVAXusdt_5m.csv until hours 2024-06-11 00:40
# 292/319:    Data written to AVAXusdt_5m.csv until hours 2024-06-14 12:00
# 293/319:    Data written to AVAXusdt_5m.csv until hours 2024-06-17 23:20
# 294/319:    Data written to AVAXusdt_5m.csv until hours 2024-06-21 10:40
# 295/319:    Data written to AVAXusdt_5m.csv until hours 2024-06-24 22:00
# 296/319:    Data written to AVAXusdt_5m.csv until hours 2024-06-28 09:20
# 297/319:    Data written to AVAXusdt_5m.csv until hours 2024-07-01 20:40
# 298/319:    Data written to AVAXusdt_5m.csv until hours 2024-07-05 08:00
# 299/319:    Data written to AVAXusdt_5m.csv until hours 2024-07-08 19:20
# 300/319:    Data written to AVAXusdt_5m.csv until hours 2024-07-12 06:40
# 301/319:    Data written to AVAXusdt_5m.csv until hours 2024-07-15 18:00
# 302/319:    Data written to AVAXusdt_5m.csv until hours 2024-07-19 05:20
# 303/319:    Data written to AVAXusdt_5m.csv until hours 2024-07-22 16:40
# 304/319:    Data written to AVAXusdt_5m.csv until hours 2024-07-26 04:00
# 305/319:    Data written to AVAXusdt_5m.csv until hours 2024-07-29 15:20
# 306/319:    Data written to AVAXusdt_5m.csv until hours 2024-08-02 02:40
# 307/319:    Data written to AVAXusdt_5m.csv until hours 2024-08-05 14:00
# 308/319:    Data written to AVAXusdt_5m.csv until hours 2024-08-09 01:20
# 309/319:    Data written to AVAXusdt_5m.csv until hours 2024-08-12 12:40
# 310/319:    Data written to AVAXusdt_5m.csv until hours 2024-08-16 00:00
# 311/319:    Data written to AVAXusdt_5m.csv until hours 2024-08-19 11:20
# 312/319:    Data written to AVAXusdt_5m.csv until hours 2024-08-22 22:40
# 313/319:    Data written to AVAXusdt_5m.csv until hours 2024-08-26 10:00
# 314/319:    Data written to AVAXusdt_5m.csv until hours 2024-08-29 21:20
# 315/319:    Data written to AVAXusdt_5m.csv until hours 2024-09-02 08:40
# 316/319:    Data written to AVAXusdt_5m.csv until hours 2024-09-05 20:00
# 317/319:    Data written to AVAXusdt_5m.csv until hours 2024-09-09 07:20
# 318/319:    Data written to AVAXusdt_5m.csv until hours 2024-09-12 18:40
# 0/27:    Data written to AVAXusdt_60m.csv until hours 2021-10-12 18:00
# 1/27:    Data written to AVAXusdt_60m.csv until hours 2021-11-23 09:00
# 2/27:    Data written to AVAXusdt_60m.csv until hours 2022-01-04 01:00
# 3/27:    Data written to AVAXusdt_60m.csv until hours 2022-02-14 17:00
# 4/27:    Data written to AVAXusdt_60m.csv until hours 2022-03-28 10:00
# 5/27:    Data written to AVAXusdt_60m.csv until hours 2022-05-09 02:00
# 6/27:    Data written to AVAXusdt_60m.csv until hours 2022-06-19 18:00
# 7/27:    Data written to AVAXusdt_60m.csv until hours 2022-07-31 10:00
# 8/27:    Data written to AVAXusdt_60m.csv until hours 2022-09-11 02:00
# 9/27:    Data written to AVAXusdt_60m.csv until hours 2022-10-22 18:00
# 10/27:    Data written to AVAXusdt_60m.csv until hours 2022-12-03 09:00
# 11/27:    Data written to AVAXusdt_60m.csv until hours 2023-01-14 01:00
# 12/27:    Data written to AVAXusdt_60m.csv until hours 2023-02-24 17:00
# 13/27:    Data written to AVAXusdt_60m.csv until hours 2023-04-07 11:00
# 14/27:    Data written to AVAXusdt_60m.csv until hours 2023-05-19 03:00
# 15/27:    Data written to AVAXusdt_60m.csv until hours 2023-06-29 19:00
# 16/27:    Data written to AVAXusdt_60m.csv until hours 2023-08-10 11:00
# 17/27:    Data written to AVAXusdt_60m.csv until hours 2023-09-21 03:00
# 18/27:    Data written to AVAXusdt_60m.csv until hours 2023-11-01 18:00
# 19/27:    Data written to AVAXusdt_60m.csv until hours 2023-12-13 10:00
# 20/27:    Data written to AVAXusdt_60m.csv until hours 2024-01-24 02:00
# 21/27:    Data written to AVAXusdt_60m.csv until hours 2024-03-05 18:00
# 22/27:    Data written to AVAXusdt_60m.csv until hours 2024-04-16 11:00
# 23/27:    Data written to AVAXusdt_60m.csv until hours 2024-05-28 03:00
# 24/27:    Data written to AVAXusdt_60m.csv until hours 2024-07-08 19:00
# 25/27:    Data written to AVAXusdt_60m.csv until hours 2024-08-19 11:00
# 26/27:    Data written to AVAXusdt_60m.csv until hours 2024-09-13 14:00

# %% [markdown]
# # 5 min

# %%
# Out:
# 0/72:    Data written to BTCusdt_5m.csv until hours 2024-01-04 11:20
# 1/72:    Data written to BTCusdt_5m.csv until hours 2024-01-07 22:40
# 2/72:    Data written to BTCusdt_5m.csv until hours 2024-01-11 10:00
# 3/72:    Data written to BTCusdt_5m.csv until hours 2024-01-14 21:20
# 4/72:    Data written to BTCusdt_5m.csv until hours 2024-01-18 08:40
# 5/72:    Data written to BTCusdt_5m.csv until hours 2024-01-21 20:00
# 6/72:    Data written to BTCusdt_5m.csv until hours 2024-01-25 07:20
# 7/72:    Data written to BTCusdt_5m.csv until hours 2024-01-28 18:40
# 8/72:    Data written to BTCusdt_5m.csv until hours 2024-02-01 06:00
# 9/72:    Data written to BTCusdt_5m.csv until hours 2024-02-04 17:20
# 10/72:    Data written to BTCusdt_5m.csv until hours 2024-02-08 04:40
# 11/72:    Data written to BTCusdt_5m.csv until hours 2024-02-11 16:00
# 12/72:    Data written to BTCusdt_5m.csv until hours 2024-02-15 03:20
# 13/72:    Data written to BTCusdt_5m.csv until hours 2024-02-18 14:40
# 14/72:    Data written to BTCusdt_5m.csv until hours 2024-02-22 02:00
# 15/72:    Data written to BTCusdt_5m.csv until hours 2024-02-25 13:20
# 16/72:    Data written to BTCusdt_5m.csv until hours 2024-02-29 00:40
# 17/72:    Data written to BTCusdt_5m.csv until hours 2024-03-03 12:00
# 18/72:    Data written to BTCusdt_5m.csv until hours 2024-03-06 23:20
# 19/72:    Data written to BTCusdt_5m.csv until hours 2024-03-10 10:40
# 20/72:    Data written to BTCusdt_5m.csv until hours 2024-03-13 22:00
# 21/72:    Data written to BTCusdt_5m.csv until hours 2024-03-17 09:20
# 22/72:    Data written to BTCusdt_5m.csv until hours 2024-03-20 20:40
# 23/72:    Data written to BTCusdt_5m.csv until hours 2024-03-24 08:00
# 24/72:    Data written to BTCusdt_5m.csv until hours 2024-03-27 19:20
# 25/72:    Data written to BTCusdt_5m.csv until hours 2024-03-31 07:40
# 26/72:    Data written to BTCusdt_5m.csv until hours 2024-04-03 19:00
# 27/72:    Data written to BTCusdt_5m.csv until hours 2024-04-07 06:20
# 28/72:    Data written to BTCusdt_5m.csv until hours 2024-04-10 17:40
# 29/72:    Data written to BTCusdt_5m.csv until hours 2024-04-14 05:00
# 30/72:    Data written to BTCusdt_5m.csv until hours 2024-04-17 16:20
# 31/72:    Data written to BTCusdt_5m.csv until hours 2024-04-21 03:40
# 32/72:    Data written to BTCusdt_5m.csv until hours 2024-04-24 15:00
# 33/72:    Data written to BTCusdt_5m.csv until hours 2024-04-28 02:20
# 34/72:    Data written to BTCusdt_5m.csv until hours 2024-05-01 13:40
# 35/72:    Data written to BTCusdt_5m.csv until hours 2024-05-05 01:00
# 36/72:    Data written to BTCusdt_5m.csv until hours 2024-05-08 12:20
# 37/72:    Data written to BTCusdt_5m.csv until hours 2024-05-11 23:40
# 38/72:    Data written to BTCusdt_5m.csv until hours 2024-05-15 11:00
# 39/72:    Data written to BTCusdt_5m.csv until hours 2024-05-18 22:20
# 40/72:    Data written to BTCusdt_5m.csv until hours 2024-05-22 09:40
# 41/72:    Data written to BTCusdt_5m.csv until hours 2024-05-25 21:00
# 42/72:    Data written to BTCusdt_5m.csv until hours 2024-05-29 08:20
# 43/72:    Data written to BTCusdt_5m.csv until hours 2024-06-01 19:40
# 44/72:    Data written to BTCusdt_5m.csv until hours 2024-06-05 07:00
# 45/72:    Data written to BTCusdt_5m.csv until hours 2024-06-08 18:20
# 46/72:    Data written to BTCusdt_5m.csv until hours 2024-06-12 05:40
# 47/72:    Data written to BTCusdt_5m.csv until hours 2024-06-15 17:00
# 48/72:    Data written to BTCusdt_5m.csv until hours 2024-06-19 04:20
# 49/72:    Data written to BTCusdt_5m.csv until hours 2024-06-22 15:40
# 50/72:    Data written to BTCusdt_5m.csv until hours 2024-06-26 03:00
# 51/72:    Data written to BTCusdt_5m.csv until hours 2024-06-29 14:20
# 52/72:    Data written to BTCusdt_5m.csv until hours 2024-07-03 01:40
# 53/72:    Data written to BTCusdt_5m.csv until hours 2024-07-06 13:00
# 54/72:    Data written to BTCusdt_5m.csv until hours 2024-07-10 00:20
# 55/72:    Data written to BTCusdt_5m.csv until hours 2024-07-13 11:40
# 56/72:    Data written to BTCusdt_5m.csv until hours 2024-07-16 23:00
# 57/72:    Data written to BTCusdt_5m.csv until hours 2024-07-20 10:20
# 58/72:    Data written to BTCusdt_5m.csv until hours 2024-07-23 21:40
# 59/72:    Data written to BTCusdt_5m.csv until hours 2024-07-27 09:00
# 60/72:    Data written to BTCusdt_5m.csv until hours 2024-07-30 20:20
# 61/72:    Data written to BTCusdt_5m.csv until hours 2024-08-03 07:40
# 62/72:    Data written to BTCusdt_5m.csv until hours 2024-08-06 19:00
# 63/72:    Data written to BTCusdt_5m.csv until hours 2024-08-10 06:20
# 64/72:    Data written to BTCusdt_5m.csv until hours 2024-08-13 17:40
# 65/72:    Data written to BTCusdt_5m.csv until hours 2024-08-17 05:00
# 66/72:    Data written to BTCusdt_5m.csv until hours 2024-08-20 16:20
# 67/72:    Data written to BTCusdt_5m.csv until hours 2024-08-24 03:40
# 68/72:    Data written to BTCusdt_5m.csv until hours 2024-08-27 15:00
# 69/72:    Data written to BTCusdt_5m.csv until hours 2024-08-31 02:20
# 70/72:    Data written to BTCusdt_5m.csv until hours 2024-09-03 13:40
# 71/72:    Data written to BTCusdt_5m.csv until hours 2024-09-07 01:00

# %% [markdown]
# # 60 min

# %%
# Out:
# 0/6:    Data written to BTCusdt_60m.csv until hours 2024-02-11 16:00
# 1/6:    Data written to BTCusdt_60m.csv until hours 2024-03-24 08:00
# 2/6:    Data written to BTCusdt_60m.csv until hours 2024-05-05 01:00
# 3/6:    Data written to BTCusdt_60m.csv until hours 2024-06-15 17:00
# 4/6:    Data written to BTCusdt_60m.csv until hours 2024-07-27 09:00
# 5/6:    Data written to BTCusdt_60m.csv until hours 2024-09-07 01:00

# %%
import requests
import datetime


coin_id = "omni"
vs_currency = "usd"

# Define start and end timestamps
start_date = datetime.datetime(2024, 1, 1)
end_date = datetime.datetime.now(datetime.timezone.utc)
from_ts = int(start_date.timestamp())
to_ts = int(end_date.timestamp())

url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart/range"
params = {
    "vs_currency": vs_currency,
    "from": from_ts,
    "to": to_ts
}

response = requests.get(url, params=params)
data = response.json()
for i in data['prices']:
    i[0] = datetime.datetime.fromtimestamp(i[0] / 1000).strftime("%d-%m-%Y")

data['prices']

# %%
import requests
import datetime
import csv
import time

COINS= [
    "singularitynet",
    "astar",
    "binancecoin",
	"binance-staked-sol",
    "bitcoin",
    "catizen",
	"dogs-2",
    "ethena",
    "ethereum",
	"eurite",
    "fetch-ai",
	"g-token",
	"hamster-kombat",
	"io",
	"notcoin",
    "omni",
	"pyth-network",
    "qtum",
    "radiant-capital",
	"renzo",
	"saga-2",
	"scroll",
    "solana",
    "the-open-network",
    "usd-coin",
    "tether",
	"usual-usd",
    "wrapped-beacon-eth"
]

# Function to fetch daily prices for a coin
def fetch_daily_prices(coin_id, start_date, end_date):
    url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart/range"
    params = {
        "vs_currency": "eur",
        "from": int(start_date.timestamp()),
        "to": int(end_date.timestamp())
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        prices = {}
        for entry in data.get("prices", []):
            # Convert timestamp to date
            timestamp = int(entry[0])
            date = datetime.datetime.fromtimestamp(timestamp / 1000).strftime("%d-%m-%Y")
            prices[date] = entry[1]  # Use price as value
        return prices
    else:
        print(f"Error fetching data for {coin_id}: {response.status_code}")
        return 0

# Start and end dates
start_date = datetime.datetime(2024, 1, 1)
end_date = datetime.datetime.now(datetime.timezone.utc)

# Fetch prices for all coins
all_prices = {}
dates = set()

for coin in COINS:
    print(f"Fetching data for {coin}...")
    prices = fetch_daily_prices(coin, start_date, end_date)
    if not prices:
        break
    all_prices[coin] = prices
    dates.update(prices.keys())
    time.sleep(1)

# Sort dates
sorted_dates = sorted(dates, key=lambda x: datetime.datetime.strptime(x, "%d-%m-%Y"))

# Write to CSV
output_file = "data2.csv"
with open(output_file, "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    header = ["Date"] + COINS
    writer.writerow(header)

    # Write rows
    for date in sorted_dates:
        row = [date] + [
            all_prices[coin].get(date, "NA") for coin in COINS
        ]  # Use "NA" if no data for that date
        writer.writerow(row)

print(f"Data saved to {output_file}")
